# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# # Employer Postings

# %%
# Specify path of employer postings:
# CB 7.16 - In future, read this from hosted db. For now, Excel file will suffice
path = "C://Users//Colin Bryan//Documents//Personal//TiO//TiO-Job-Connections//data//TiO - Employer Partner Job Postings.xlsx"

# Create employer postings dataframe and return URLs
def get_employer_postings(path):

    # Read file path into dataframe
    postings_df = pd.read_excel(path)

    # Drop NaNs
    postings_df.dropna(subset = ['Opening URL'], inplace = True)
    
    # Save URLs into a list
    url_list = list(postings_df['Opening URL'])

    return postings_df, url_list

def scrape_indeed_postings(url_list):
    
    # Create list of indeed_postings onl
    indeed_url_list = []
    
    # Get list of posts from Indeed
    for url in url_list:
        if 'indeed.com' in url:
            indeed_url_list.append(url)
    
    # Create lists to store data
    job_titles = []
    job_locations = []
    job_descriptions = []

    # Get data from each Indeed URL:    
    for url in indeed_url_list:
        
        # Get html data from the URL
        html_data = requests.get(url).text
        
        # Pass into parser
        soup = BeautifulSoup(html_data, 'html.parser')
        
        # Save job titles and locations into list
        try:
            # Get page title
            page_title = soup.title.get_text(strip = True)
            
            # Split page title to get job title and location
            job_title = page_title.split(' - ')[0]            
            location = page_title.split(' - ')[1]
            
            # If there is a hyphen in the job title, resplit. 
            # Hypothesis is that a location will be missing a comma if there is a hypen in the title and it's not remote
            if ',' not in location:
                if 'remote' not in location.lower():
                    # Split page title to get job title and location
                    job_title = page_title.split(' - ')[0] + ' - ' + page_title.split(' - ')[1]         
                    location = page_title.split(' - ')[2]
            
            # Append title and location to lists
            job_titles.append(job_title)
            job_locations.append(location)
            
        except:
            job_titles.append('Could not find title')
            job_locations.append('Could not find location')
        
        # Save job descriptions into list
        try:
            job_descriptions.append(
                soup.select_one("#jobDescriptionText").get_text(strip=True, separator="\n")
            )
        except:
            job_descriptions.append('Could not find description')
            
        
    # Package up everything into dataframe by creating dictionary first
    indeed_dict = {'Title':job_titles, 'Location':job_locations, 'Description':job_descriptions, 'URL':indeed_url_list}

    # Create dataframe
    indeed_df = pd.DataFrame(indeed_dict)
    
    # Drop rows that didn't return results
    indeed_df = indeed_df[indeed_df['Description'] != 'Could not find description'].reset_index(drop=True)
    
    return indeed_df

# %%
employer_df, url_list = get_employer_postings(path)

# %%
df = scrape_indeed_postings(url_list)

# %%
df
# Out:
#                                 Title                Location  \
# 0                   Controls Engineer     Souderton, PA 18964
# 1                 MECHANICAL ENGINEER     Souderton, PA 18964
# 2                       JANITOR FT/PT     Souderton, PA 18964
# 3       Payroll Specialist/HR Support     Souderton, PA 18964
# 4           INDUSTRIAL COATING HELPER     Souderton, PA 18964
# 5                  Production Manager     Souderton, PA 18964
# 6                              WELDER     Souderton, PA 18964
# 7              Junior Buyer/Purchaser     Souderton, PA 18964
# 8                 MILLWRIGHT MECHANIC     Souderton, PA 18964
# 9               Assembler - 1st Shift       Malvern, PA 19355
# 10                  Company Concierge       Malvern, PA 19355
# 11     Manufacturing Welding Engineer       Malvern, PA 19355
# 12                  Company Concierge       Malvern, PA 19355
# 13  Mechanical Engineering Technician       Malvern, PA 19355
# 14     Engineering Change Coordinator       Ivyland, PA 18974
# 15                Cost Accountant III       Ivyland, PA 18974
# 16                    YZ Assembler II       Ivyland, PA 18974
# 17         Warehouse Material Handler       Ivyland, PA 18974
# 18                  Quality Inspector       Ivyland, PA 18974
# 19                       Senior Buyer       Ivyland, PA 18974
# 20                  CNC Machinist III       Ivyland, PA 18974
# 21                   Quality Engineer       Ivyland, PA 18974
# 22            Inventory Cycle Counter  Concordville, PA 19331
# 23        Inside Sales Representative        Concordville, PA
# 24                       Assembler II        Concordville, PA
# 25                 Material Associate        Concordville, PA
# 26    Customer Service Representative        Concordville, PA
# 27                       Mold Maker A        Concordville, PA
# 28         Plastic Injection Operator        Concordville, PA
#
#                                           Description  \
# 0   Are you ready to break free of the mundane?\nL...
# 1   MECHANICAL ENGINEER\nWe are currently seeking ...
# 2   Are you ready to join a winning team?\nLooking...
# 3   Are you ready to join a winning team?\nLooking...
# 4   INDUSTRIAL COATING HELPER\nAre you ready to jo...
# 5   Are you ready to break free of the mundane?\nL...
# 6   WELDERS 1ST AND 2ND SHIFT\nAre you ready to jo...
# 7   Are you ready to join a winning team?\nLooking...
# 8   MILLWRIGHT MECHANIC\nAre you ready to break fr...
# 9   *We are currently offering a $1000 sign-on bon...
# 10  This position resides at ifm prover USA in Mal...
# 11  This role is for the experienced engineer who ...
# 12  This position resides at ifm prover USA in Mal...
# 13  This position resides in the ifm prover USA Ma...
# 14  Location: Ivyland, PA, US, 18974-1706\nReq ID:...
# 15  Location: Ivyland, PA, US, 18974-1706\nReq ID:...
# 16  Location: Ivyland, PA, US, 18974-1706\nReq ID:...
# 17  Location: Ivyland, PA, US, 18974-1706\nReq ID:...
# 18  Location: Ivyland, PA, US, 18974-1706\nReq ID:...
# 19  Location: Ivyland, PA, US, 18974-1706\nReq ID:...
# 20  Location: Ivyland, PA, US, 18974-1706\nReq ID:...
# 21  Location: Ivyland, PA, US, 18974-1706\nReq ID:...
# 22  Overview\nTo audit the accuracy of the invento...
# 23  Southco is the leading global manufacturer of ...
# 24  Southco is the leading global manufacturer of ...
# 25  Southco is the leading global manufacturer of ...
# 26  Southco is the leading global manufacturer of ...
# 27  Southco is the leading global manufacturer of ...
# 28  Southco is the leading global manufacturer of ...
#
#                                                   URL
# 0   https://www.indeed.com/viewjob?jk=80d9cb72bee4...
# 1   https://www.indeed.com/viewjob?jk=e2579ee28fab...
# 2   https://www.indeed.com/viewjob?jk=f68b80a593f2...
# 3   https://www.indeed.com/viewjob?jk=5ffd7d307573...
# 4   https://www.indeed.com/viewjob?jk=aef5651413f2...
# 5   https://www.indeed.com/viewjob?jk=0a7a4f606c7a...
# 6   https://www.indeed.com/viewjob?jk=0d1089220c54...
# 7   https://www.indeed.com/viewjob?jk=b9ff8f377567...
# 8   https://www.indeed.com/viewjob?jk=8ba9de851371...
# 9   https://www.indeed.com/viewjob?jk=b0d3146de697...
# 10  https://www.indeed.com/viewjob?jk=e831c053b327...
# 11  https://www.indeed.com/viewjob?jk=75623be536e7...
# 12  https://www.indeed.com/viewjob?jk=e831c053b327...
# 13  https://www.indeed.com/viewjob?jk=2fd155710e3c...
# 14  https://www.indeed.com/viewjob?jk=ae2c78e21464...
# 15  https://www.indeed.com/viewjob?jk=c836c812d7da...
# 16  https://www.indeed.com/viewjob?jk=9e054b7c7660...
# 17  https://www.indeed.com/viewjob?jk=e1e783d716bb...
# 18  https://www.indeed.com/viewjob?jk=48eb8aee26bb...
# 19  https://www.indeed.com/viewjob?jk=91c54996225a...
# 20  https://www.indeed.com/viewjob?jk=e082a9942710...
# 21  https://www.indeed.com/viewjob?jk=905ab75a415e...
# 22  https://www.indeed.com/viewjob?jk=0d07eaec0b50...
# 23  https://www.indeed.com/viewjob?jk=4e028f437956...
# 24  https://www.indeed.com/viewjob?jk=2dbadf8dbfd0...
# 25  https://www.indeed.com/viewjob?jk=47956348ce50...
# 26  https://www.indeed.com/viewjob?jk=7965765adc71...
# 27  https://www.indeed.com/viewjob?jk=8d4189de3fd1...
# 28  https://www.indeed.com/viewjob?jk=3b012b408c9d...

# %%
sub_df = df[df['Location'].str.contains('Concordville')]

# %%
sub_df.Location.unique()
# Out:
# array(['Concordville, PA 19331', 'Concordville, PA'], dtype=object)

# %% [markdown]
# # API

# %%
def skills_API(skill):
    # Use API Layer's skills database
    url = "https://api.apilayer.com/skills?q={}".format(skill)

    # CB 7.16 - Hide API key in a secrets file before sharing?
    headers= {
    "apikey": ""
    }

    # Get response and result
    response = requests.request('GET', url, headers=headers)
    result = response.json()
    
    if response.status_code == 200:
        return result
    raise Exception(result.get('message'))

# %%
response = skills_API('java')

# %%
response
# Out:
# ['Java',
#  'Java2D',
#  'JavaFX',
#  'Java3D',
#  'Java 6',
#  'Java 5',
#  'JavaSE',
#  'JavaCC',
#  'JavaOS',
#  'Java 1']

# %%
5 % 3
# Out:
# 2
